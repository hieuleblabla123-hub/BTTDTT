# %%
def tinhtong(n):
    tong=0
    for i in range(1,n+1):
        tong+=i
    return tong
a=tinhtong(1000)
print (a)
# Out:
# 500500

# %%
try:
    a=int(input(""))
    if a<=0:
        raise ValueError("nhap so duong")
    lst=[]
    for i in range(1,a+1):
        if a%i==0:
            lst.append(i)
            b=len(lst)
    if b==2:
        print("la so nguyen to")
    else:
        print("khong la so nguyen to")
except Exception as loi:
    print (loi)
# Out:
# khong la so nguyen to

# %%
a=int(input(""))
tich=1
for i in range(1,a+1):
    tich*=i
print(tich)
# Out:
# ...

# %%
a=int(input(""))
count=1
if a==0:
    print("so luong so =1")
else:
    while a>=10:
        a=a//10
        count+=1
    print(count)
# Out:
# 3

# %%
try:
    a=int(input(""))
    if a<=0:
        raise ValueError("nhap so duong")
    lst=[]
    for i in range(1,a+1):
        if a%i==0:
            lst.append(i)
            b=len(lst)
    if b==2:
        print("la so nguyen to")
    else:
        print("khong la so nguyen to")
except Exception as loi:
    print (loi)
# Out:
# khong la so nguyen to

# %%
try:
    n=int(input())
    if n<=0:
        raise ValueError("nhap so duong")
    songuyento=[]
    for i in range(1,n+1):
        lst=[]
        for j in range(1,i+1):
            if i%j==0: 
                lst.append(j)
        for x in lst:
            if len(lst)==2:
                songuyento.append(i)
    print(songuyento)
except Exception as b:
    print (b)
# Out:
# []

# %%
try:
    n=int(input())
    souoc=[]
    snt=[]
    if n<=0:
        raise ValueError("nhap so duong")
    for i in range(n-1,0,-1):
        if n%i==0:
            souoc.append(i)
            break
    for x in souoc:    
        snt.append(x)
        print(snt)
except Exception as loi:
    print(loi)
# Out:
# [50]

# %%
print("--- Bài toán: ChickenAndDog ---")
# Nhập dữ liệu
tong_con = int(input("Nhập tổng số con: "))
tong_chan = int(input("Nhập tổng số chân: "))
1,1, tong_con
2,4, tong_chan
Sx=tong_con*4-tong_chan
Sy=tong_chan-2*tong_con
x=Sx//2
y=Sy//22
print(x,y)
# Out:
# --- Bài toán: ChickenAndDog ---
# 394 -18

# %%
try:
    a = int(input("Nhập tổng số : "))
    b = int(input("Nhập tổng số : ")) 
    lsta=[]
    lstb=[]
    for i in range(a, 0, -1):
        if a%i==0:
            lsta.append(i)
    for j in range(b, 0, -1):
        if b%j==0:
            lstb.append(j)
    for m in lsta: 
        for n in lstb:   
            if m == n: 
                print(m)
            break  
except Exception as loi:
    print (loi)
# Out:
# 50
