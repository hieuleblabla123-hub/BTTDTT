# %%
ten = input ("Vui long nhap ten cua ban: ")
tuoi = int(input("Vui long nhap tuoi cua ban: "))
print ("Xin chao " + ten + " dang " + str(tuoi) + " tuoi.")

# %%
#W2A3

    a = int(input("nhap a: "))
    b = int(input("nhap b: "))
    c = a + b
    print(f"Tong= {c}")
    Z = a - b
    print(f"Hieu= {Z}")
    d = a * b
    print(f"Tich = {d}")
    if b == 0:
        print("Khong the chia cho 0")
    else:
        e = a / b
        print(f"thuong = {e}")
        f = a % b
        print(f)

# %%
#w2a4
dulieu = input("Nhap vao chuoi so cach nhau boi dau phay: ")
diemso = dulieu.split(",")
if len(diemso) !=6:
    print("Vui long nhap dung 6 diem so")
    exit()  
a1, b1, c1, a2, b2, a3 = map(float, diemso)

DTB = ((a1 + b1 + c1) + (a2+b2)*2 + a3*3)/10
DTB_ok= round(DTB,2)    
print(f"Diem trung binh = {DTB_ok}")

# %%
#w2a5
a= int(input("Nhap co so"))
b= int(input("Nhap so mu"))
c= a**b
print(f"Ket qua={c}")

# %%
#w2a6
a= input("mot chu thuong= ")

b=ord(a)

print(f"so unicode cua a {b}")

sohoa= b-32
chuhoa= chr(sohoa)
print(f"ky tu hoa la: {chuhoa}")

# %%
# W2A7
A = ((13 ** 2) * 3) + 5

B = 13 ** 2 * 3 + 5

print(f"Kết quả của biểu thức A: {A}")
print(f"Kết quả của biểu thức B: {B}")

# %%
#W2A8

a= float(input("Do C hien tai la" ))
f= (a*9/5)+32
print(f"Do F tuong ung la: {f}")

# %%
#W2A9
x= float(input("USD: "))
vnd= x+ x*3/10 +x*1/10 +10 
tien= round (vnd, 5)

print(f"So tien VND phai tra la: {tien}")

# %%
#W2A10
ten = input("Nhap vao 3 ten cach nhau boi dau phay: ")
danhsachten = ten.split(",")
ten1, ten2, ten3 = danhsachten
print(f''"xinchao",ten3, ten2, ten1)

# %%
#W2A11
gio= int(input("Nhap so gio: "))
phut= int(input("Nhap so phut: "))
tonggiay= gio*3600 + phut*60

print(f"Tong so giay la: {tonggiay}")

# %%
#W2A13
a= int(input("Nhap so a: "))
b= int(input("Nhap so b: "))
c= a*b 
d= str(c)[-1]
print(f"So don vi cua c la: {d}")

# %%
#W2A14
z = input("Nhập 2 số a,b cách nhau bằng dấu phẩy: ")
b=z.split(",")
ten1, ten2=b
print(f"a={ten2}, b={ten1}")

# %%
#W2A15

# %%
#W2A16
mua=("xuan", "ha", "thu", "dong")
print(*mua, sep='\n')

# %%
#W2A17
n = int(input("Nhập so nguyen n: "))

# Chiều rộng tối đa cố định (Max Width) của hàng cuối cùng
# Công thức: 2*n - 1
max_width = 2 * n - 1

# Lặp qua n hàng. i sẽ chạy từ 1 đến n (số thứ tự của hàng)
for i in range(1, n + 1):
    
    # 1. Tính số ký tự Z (luôn là số lẻ: 1, 3, 5, ...)
    num_chars = 2 * i - 1
    a = "Z" * num_chars
    
    print( a.center(max_width, "-"))

# %%
#W2A18 
# Hàng 1
print("###   ##   ###   ###")
# Hàng 2
print(" #   # #    #     # ")
# Hàng 3
print(" #   # #    #     # ")
# Hàng 4
print(" #   # #    #     # ")
# Hàng 5
print(" #   ##     #     # ")

# %%
#W2A19 
a= ("monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday")
print(*a, sep='\n')

# %%
#W2A20
a= ("january", "february", "march", "april", "may", "june", "july", "august", "september", "october", "november", "december")
print(*a, sep='\n')

# %%
#W2A21
a= (f'Hello Word!')
for i in range (10):
    print(a)

# %%
#W2A21 b
a= (f'Hello Word!')
i=0
while i<10:
    i+=1
    print(a)
# Out:
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
# Hello Word!
